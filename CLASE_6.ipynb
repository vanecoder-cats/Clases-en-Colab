# %% [markdown]
# <a href="https://colab.research.google.com/github/vanecoder-cats/Clases-en-Colab/blob/main/CLASE_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones para tipos de datos.
#
# La función `type()` regresa el tipo de dato o clase a la que pertenece un objeto el cual es ingresado como argumento con la siguiente sintaxis:
#
# `type(<objeto>)`
#
# **Ejemplos:**
#
# Las siguientes celdas utlizarán la función type() para conocer el tipo de datos del que se trata.

# %%
type("Hola")
# Out:
# str

# %%
type(b"Hola")
# Out:
# bytes

# %%
type(12)
# Out:
# int

# %%
type(12.)
# Out:
# float

# %%
type(23j)
# Out:
# complex

# %%
type(True)
# Out:
# bool

# %%
type([1, 2, 3])
# Out:
# list

# %%
type((1, 2, 3))
# Out:
# tuple

# %%
type({1, 2, 3})
# Out:
# set

# %%
type({'uno': '1'})
# Out:
# dict

# %% [markdown]
# ## La función int().
# Esta función transforma un objeto compatible que es ingresado como argumento a un objeto tipo int.
#
# La sintaxis es la siguiente:
#
# `int(<objeto>)`
#
#
#
# *   Es posible convertir objetos de tipo `str `que representen correctamente a un número entero.
# *   Los objetos de tipo `float` son truncados en la parte entera.
# *  ** True** es convertido en 1.
# *   **False** es convertido en 0.
# *   La función `int()` no es compatible con objetos tipo **complex**.
#
#
# **Ejemplo:**
# La siguiente celda convertirá en un objeto **int** al objeto de tipo **bool** que se ingresa como argumento.

# %%
int(True)
# Out:
# 1

# %% [markdown]
# El argumento de la siguiente celda contiene una representación correcta de un entero negativo, por lo que la función **int()** podrá realizar la conversión correctamente.

# %%
int("-12")
# Out:
# -12

# %% [markdown]
# El argumento de la siguiente celda contiene una representación correcta de un número real, por lo que la función **int()** no podrá realizar la conversión correctamente y regresará un error de tipo **ValueError**.

# %%
int("28.8")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1399237691.py in <cell line: 0>()
# ----> 1 int("28.8")
#
# ValueError: invalid literal for int() with base 10: '28.8'

# %%
int(b"12")
# Out:
# 12

# %% [markdown]
# El argumento de la siguiente celda no contiene una representación correcta de un número entero, por lo que la función **int()** será incapaz de realizar la conversión y desencadenará un error de tipo **ValueError**.

# %%
int('Hola')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4246956786.py in <cell line: 0>()
# ----> 1 int('Hola')
#
# ValueError: invalid literal for int() with base 10: 'Hola'

# %% [markdown]
# Los argumentos de las siguiente celdas contienen objetos tipo float, por lo que la función int() truncará el valor a enteros.

# %%
int(5.6)
# Out:
# 5

# %%
int(-5.3)
# Out:
# -5

# %% [markdown]
# Los argumentos de las siguientes celdas son objetos de tipo complex, por lo que la función int() será incapaz de realizar la conversión y desencadenará un error de tipo TypeError.

# %%
int(12 + 45.2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-205804161.py in <cell line: 0>()
# ----> 1 int(12 + 45.2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(-5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2311201952.py in <cell line: 0>()
# ----> 1 int(-5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# El argumento de la siguiente celda es **None**, el cual no puede ser representado por algún valor numérico, lo que desencadenará un error de tipo **TypeError**.

# %%
int(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4024464104.py in <cell line: 0>()
# ----> 1 int(None)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %% [markdown]
# ## La función float().
#
# Transforma a un objeto de tipo compatible que se ingrese como argumento a uno de tipo float.
#
# La sintaxis es la siguiente:
#
# `float(<objeto>)`
#
#
# *   Puede convertir objetos de tipo **str** que contengan una representación correcta a un número real.
# *  Es compatible con los objetos tipo int.
# *   **True** es convertido en **1.0**
# *  ** False** es convertido en **0.0.**
# *   No es compatible con objetos tipo **complex**.
#
#
# **Ejemplos**:
#
# El argumento de la siguiente celda contiene una representación correcta de un número real, por lo que la función **float()** podrá realizar la conversión correctamente.

# %%
float("-12.6")
# Out:
# -12.6

# %% [markdown]
# El argumento de la siguiente celda no contiene una representación correcta de un número, por lo que la función **float()** será incapaz de realizar la conversión y desencadenará un error de tipo **ValueError**.

# %%
float('Hola')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2324806637.py in <cell line: 0>()
# ----> 1 float('Hola')
#
# ValueError: could not convert string to float: 'Hola'

# %% [markdown]
# El argumento de la siguiente celda es un objeto de tipo int, por lo que la función float() será capaz de realizar la conversión.

# %%
float(-5)
# Out:
# -5.0

# %% [markdown]
# El argumento de la siguiente celda es un objeto de tipo complex, por lo que la función **float()** será incapaz de realizar la conversión y desencadenará un error de tipo **TypeError**.

# %%
float(12.5 + 33j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3627877289.py in <cell line: 0>()
# ----> 1 float(12.5 + 33j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(True)
# Out:
# 1.0

# %%
float(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-370574591.py in <cell line: 0>()
# ----> 1 float(None)
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'

# %% [markdown]
# ## La función complex().
#
# Transforma a un objeto compatible a uno de tipo **complex.**
#
# * Convierte objetos de tipo **str** que contengan representen correctamente a un **número real**.
# * Transforma en un objeto de tipo complex a un par de números ya sean **int** o **float**.
# * Si sólo se da un número int o float, este será identificado como el componente real y el componente complejo será 0j.
#
#
# **Ejemplos:**

# %%
complex(3.5, 2)
# Out:
# (3.5+2j)

# %%
complex(8.3)
# Out:
# (8.3+0j)

# %%
complex("23+5j")
# Out:
# (23+5j)

# %%
complex("23")
# Out:
# (23+0j)

# %%
complex("23+5j")
# Out:
# (23+5j)

# %% [markdown]
# # **La función bool().**
#
# Transforma en booleano a un objeto.
#
# * El **0** equivale a **False**.
# * El valor **None** equivale a **False**.
# * Una colección **vacía** equivale a **False**.
# * Cualquier otra cosa distinta es **True**.
#
#
#
# **Ejemplos:**

# %%
bool(-3)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool((12, 4, 78))
# Out:
# True

# %%
bool("Hola")
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(None)
# Out:
# False

# %% [markdown]
# ## La función str().
#
# Transforma a un objeto que es ingresados como argumento en una cadena de caracteres de tipo str.
#
# La sintaxis es la siguiente:
#
# str(<objeto>)
# Prácticamente todos los objetos pueden ser transformados en una cadena de caracteres.
#
# **Ejemplos:**
#
# Las siguientes celdas transformarán un objeto a str.

# %%
str(True)
# Out:
# 'True'

# %%
str(12 + 3.5j)
# Out:
# '(12+3.5j)'

# %%
str({'nombre': 'Juan'})
# Out:
# "{'nombre': 'Juan'}"

# %%
str(b'Saludos', encoding="ascii")
# Out:
# 'Saludos'

# %% [markdown]
# ## La función bytes().

# %%
bytes('Saludos', encoding='utf-8')
# Out:
# b'Saludos'

# %%
bytes(6)
# Out:
# b'\x00\x00\x00\x00\x00\x00'

# %%
bytes(True)
# Out:
# b'\x00'

# %%
bytes(False)
# Out:
# b''

# %%
bytes(-1.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1614485643.py in <cell line: 0>()
# ----> 1 bytes(-1.4)
#
# TypeError: cannot convert 'float' object to bytes

# %%
bytes(12 + 3.5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-844435317.py in <cell line: 0>()
# ----> 1 bytes(12 + 3.5j)
#
# TypeError: cannot convert 'complex' object to bytes

# %%
bytes({'nombre': 'Juan'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2468823967.py in <cell line: 0>()
# ----> 1 bytes({'nombre': 'Juan'})
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# # **Expresiones con operadores.**
#
# Los operadores son signos o palabras reservadas que el intérprete de Python identifica dentro de sus sintaxis para realizar una acción (operación) específica.
#
#
#
# ```
# <objeto 1> <operador> <objeto 2>
# <objeto 1> <operador 1> <objeto 2> <operador 2> .... <operador n-1> <objeto n>
# ```
#
#
# **Ejemplo:**

# %%
15 * 4 + 1 / 3 ** 5  #60+1/3^5=60+1/243
# Out:
# 60.00411522633745

# %% [markdown]
# ![OPERADOR ARITMETICO.jpg](data:image/jpeg;base64,...)
#
# ##Operadores aritméticos.
#
# Los operadores arítmétricos permiten realizarf operaciones de esta índole con objetos numéricos.
#
#
#
#
# Nota: Aún cuando no afecta a la sintaxis, el uso de espacios entre los operadores aritméticos mejora la comprensión de las operaciones. Para mayor referencia remitirse al PEP-8.
#
# **Ejemplos:**
#
# Las siguientes celdas ejemplifican el uso de operadores aritméticos.

# %%
3 + 2
# Out:
# 5

# %%
3 - 2
# Out:
# 1

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
3 ** 0.5 #raíz cuadrada de 3
# Out:
# 1.7320508075688772

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2 # int(3 / 2)
# Out:
# 1

# %%
8 % 5 # 8(mod5); se refiere a que si divido 8 entre 5, ¿cuánto me sobra?
# Out:
# 3

# %%
24 % 5
# Out:
# 4

# %%
# las 17 horas qué hora es en formato <=12
17 % 12
# Out:
# 5

# %% [markdown]
# ### Reglas de precedencia en operaciones aritméticas.
#
# Los operadores se apegan a la siguiente regla de precedencia siguiendo una secuencia de izquierda a derecha:
#
# * Paréntesis.
# * Exponente.
# * Multiplicación.
# * División.
# * Suma.
# * Sustracción.
#
# **Ejemplos:**
#
# La siguiente celda realizará una operación entre números enteros apegada a las reglas de precedencia descitas previamente:
#
#
#
# 1.   Se ejecutará 4 ** 2, lo que dará por resultado 12 * 5 + 2 / 16.
# 2.   Se ejecutará 12 * 5, lo que dará por resultado 60 + 2 / 16
# 3.   Se ejecutará 2 / 16, lo que dará por resultado 60 + 0.125

# %%
12 * 5 + 2 / (4 ** 2)
# Out:
# 60.125

# %%
15 / 5 % 3 # el % va intermedio entre sumas y productos; divisiones y multiplicaciones --> congruencias --> sumas y restas
# Out:
# 0.0

# %% [markdown]
# Las siguientes celdas incluyen paréntesis, los cuales permiten **agrupar** operaciones aritméticas.

# %%
(12 * 5) + (2 / (4 ** 2))
# Out:
# 60.125

# %%
(12 * 5) + (2 / 4) ** 2
# Out:
# 60.25

# %%
(12 * (5 + 2) / 3) ** 2
# Out:
# 784.0

# %% [markdown]
# También la **conversión** entre tipo de datos entra en la jerarquía de operaciones.

# %%
(12 * 5) + (2 / (4 ** int("2")))
# Out:
# 60.125

# %% [markdown]
# En Python 3 las divisiones entre objetos de tipo int dan como resultado un objeto de tipo float. En Python 2 las divisiones entre objetos de tipo int dan por resultado la parte entera de la división.
#
# **Ejemplos:**
#
#
# ```
# >>> 3 / 4
# 0
# >>> 10 / 5
# 2
# >>>
# ```
#
# **Operadores para colecciones ordenadas.**
#
# Los objetos de tipo *str, bytes, bytearray list y tuple* permiten utilizar los siguientes operadores.
#
# El operador de ***concatenación +***.
# Este operador se utiliza para unir una después de otra a colecciones del mismo tipo en una nueva colección.
#
# `<colección 1 > + <colección 2>`
#
# **Ejemplos:**
#
# Las siguientes celdas ejemplifican operaciones válidas con el operador **+**.

# %%
"hola" + "mundo"
# Out:
# 'holamundo'

# %%
"hola" + " " + "mundo"
# Out:
# 'hola mundo'

# %%
"hola "+"mundo"
# Out:
# 'hola mundo'

# %%
[1, 2, 3] + ['uno', 'dos']
# Out:
# [1, 2, 3, 'uno', 'dos']

# %% [markdown]
# La siguiente celda intentará utilizar el **operador +** con colecciones que soportan a dicho operador pero son de distinto tipo, lo cual desencadenará un error de tipo **TypeError.**

# %%
[1, 2, 3] + ('uno', 'dos', 'tres')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-424503614.py in <cell line: 0>()
# ----> 1 [1, 2, 3] + ('uno', 'dos', 'tres')
#
# TypeError: can only concatenate list (not "tuple") to list

# %% [markdown]
# La siguiente celda intentará utilizar el **operador +** con el objeto 3 que no soporta a dicho operador, lo cual desencadenará un error de tipo TypeError.

# %%
'hola' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3032264305.py in <cell line: 0>()
# ----> 1 'hola' + 3
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Si quisieramos concatenar la palabra hola con el **sìmbolo** del **número 3**, la sintaxis serìa:

# %%
"hola"+str(3)
# Out:
# 'hola3'

# %% [markdown]
# ## El operador de repetición *.
#
# Este operador se utiliza para crear una colección que contiene el contenido de una colección que se repite un número determinado de veces.
#
# `<colección > * <n>`
#
# Donde `<n>` es un número entero.
#
# Nota: El orden de los factores no altera al producto.
#
# **Ejemplos:**

# %%
'hola' * 3
# Out:
# 'holaholahola'

# %%
3 * 'hola'
# Out:
# 'holaholahola'

# %%
(None,) * 6 # no es lo mismo que (none)
# Out:
# (None, None, None, None, None, None)

# %%
(None,)
# Out:
# (None,)

# %%
[1, 2, 3] * [3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-14759334.py in <cell line: 0>()
# ----> 1 [1, 2, 3] * [3]
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
[1,2,3] * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# ## **Operadores de asignación.**
#
#
#
#
# Los operadores de asignación se utilizan para enlazar a un nombre con un objeto/valor en el espacio de nombres.
#
# El operador de asignación = es el más conocido, sin embargo existen otros operadores de asignación tales como:
# ![OPERADOR DE ASIGNACION.jpg](data:image/jpeg;base64,...)
#
#
#
# **Ejemplos:**
#
# A continuación se ejemplifica el uso de algunos operadores de asignación.

# %%
x = 2

# %%
x
# Out:
# 2

# %%
x += 3 # x = x + 3

# %%
x
# Out:
# 5

# %%
x **= 3 # x = x ** 3

# %%
x
# Out:
# 125

# %%
x //= 14.2 # x = x // 14.2

# %%
x
# Out:
# 8.0

# %%
x %= 1.5 # x = x % 1.5

# %%
x
# Out:
# 0.5

# %%
tupla = (1, 2, 3)

# %%
tupla += ('cuatro', 'cinco', 'seis') # x = x + y

# %%
tupla
# Out:
# (1, 2, 3, 'cuatro', 'cinco', 'seis', 'cuatro', 'cinco', 'seis')

# %% [markdown]
# ## Expresiones lógicas.
#
# **Operadores de evaluación.**
#
# Estos operadores evalúan si dos expresiones cumplen con una condición específica. El resultado de esta evaluación es un objeto de tipo **bool**.
#
# ![OPERADOR LOGICO.jpg](data:image/jpeg;base64,...)
#
#
# **Ejemplos:**
#
# La siguiente celda evalúa si los valores de los objetos "hola" y 'hola' son iguales. El resultado es **True.**

# %%
"hola" == 'hola'
# Out:
# True

# %% [markdown]
# **La** siguiente celda evalúa si los valores de los objetos "hola" y 'Hola' son distintos. El resultado es True.

# %%
"hola" != 'Hola'
# Out:
# True

# %%
"hola" == "Hola"
# Out:
# False

# %% [markdown]
# La siguiente celda evalúa si el valor de5 es mayor que 3 . El resultado es **True.**

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
# 5 > 3

# %%
5>3
# Out:
# True

# %% [markdown]
# La siguiente celda evalúa si el valor de5 es menor o igual que 3 . El resultado es **False.**

# %%
5 <= 3
# Out:
# False

# %% [markdown]
# La siguiente celda evalúa si el resultado de la expresión 2 * 9 ** 0.5 es igual a 6 . El resultado es **True.**

# %%
2 * 9 ** 0.5 == 6
# Out:
# True

# %% [markdown]
# La siguiente celda evalúa si el resultado de la expresión (2 * 9) ** 0.5 es igual a 6 . El resultado es **False.**

# %%
(2 * 9) ** 0.5 == 6
# Out:
# False

# %%
(2 * 9) ** 0.5
# Out:
# 4.242640687119285

# %%
lista1 = [11,11,5]
lista2 = [11,11,5]
lista1 < lista2
# Out:
# False

# %% [markdown]
# ### **Operadores de identidad.**
#
# Los operadores **is** e **is not** evalúan si un identificador se refiere exactamente al mismo objeto o pertenece a un ***tipo***.
# ![OPERADOR DE IDENTIDAD.jpg](data:image/jpeg;base64,...)
#
#
#
# **Ejemplos:**

# %%
a = 45
b = 45

# %%
a is b
# Out:
# True

# %%
type("Hola") is str
# Out:
# True

# %%
type("Hola") is not complex
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
type(True) is not 1
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipython-input-3062249141.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   type(True) is not 1
# True

# %% [markdown]
# ## Operadores de pertenencia.
#
# Los operadores **in** y **not in** evalúan si un objeto se encuentra dentro de otro. Esto implica implícitamente que el segundo objeto es una colección.
#
# **Ejemplos:**

# %%
'a' in 'Hola'
# Out:
# True

# %%
'z' in 'Hola'
# Out:
# False

# %%
'la' not in 'Hola'
# Out:
# False

# %%
'z' not in 'Hola'
# Out:
# True

# %%
x=234
y=str(234)

# %%
y
# Out:
# '234'

# %%
str(2) in y
# Out:
# True

# %%
type(y)
# Out:
# str
