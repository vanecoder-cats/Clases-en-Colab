# %% [markdown]
# <a href="https://colab.research.google.com/github/vanecoder-cats/Clases-en-Colab/blob/main/CLASE2_EXPRESIONES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Expresiones y comentatrios
#
# Expresiones.
# Una expresion es una combinación de nombres, objetpos, operadores, funciones y métodos cuya síntaxis es correcta para el interprete de Python y que puede dar por resultado un valor.
# Ejemplos:
#
# La siguente celda es una expresión de la asignación la cual liga el nombre `numero` al objeto `78.3` mediante el operador de la asignación

# %%
numero = 78.3

# %% [markdown]
# La siguiente es una expresion que despliega el objeto relacionado con el nombre `numero`

# %%
    #titloe
    numero
# Out:
# 78.3

# %%
# title
numero
# Out:
# 78.3

# %% [markdown]
# La siguiente es una expresión aritmética que implica valores numéricos y el operador

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# La siguiente es una expresión de relación que evalúa si 20 es mayor o igual a 10 usando el operador >=

# %%
20>= 10
# Out:
# True

# %%
15 <= (5 * 5) - 10
# Out:
# True

# %% [markdown]
# La siguiente es una expresión ejecuta el método upper() , propio de los objetos tipo str mediante el operador de atributos .. En este caso, convierte todas las letras del texto en mayúsculas

# %%
"carro" .upper()
# Out:
# 'CARRO'

# %%
"popocatepetl" .upper()
# Out:
# 'POPOCATEPETL'

# %% [markdown]
# La siguiente celda ejecuta una expresión que invoca a la función 1en()

# %%
len("Trecientos es un número en formato texto")
# Out:
# 40

# %%
len("200000")
# Out:
# 6

# %% [markdown]
# Ejecución de varias expresiónes en una sola linea
# El interprete de Python permite ejecutar multiples expresónes en una sola linea, denotando el final de una expresión usando el signo de punto y coma ;
#
# Al usar esta sintaxis, el interprete solo se desplegara el resultado de la ultima expresión ejecutada
#
# Ejemplos:
#
# A continuación se ejecutaran varias expresiónes en una sola linea. Todas las exprexiónes se ejecutaron, pero solo la última será desplegada

# %%
a = 10; "Hola".upper(); a + 5
# Out:
# 15

# %%
a
# Out:
# 10

# %%
b = 8; b + 2
# Out:
# 10

# %%
b
# Out:
# 8

# %% [markdown]
# Si la última expresión también termina con un punto y coma, tampoco será desplegada

# %%
a = 10; a += 11; "amigos" * 3; a == 1;

# %%
a
# Out:
# 21

# %% [markdown]
# Advertencia: No se recomienda usar este recurso ya que se corre el riesgo de ofuscar el código innecesariamente
#
# Expresiones en el entorno interactictivo. La interfaz interactiva evalúa las expresiones tan pronto como son ingresadas y en su caso despliega el resultado
#
# Ejemplo La siguientes celdas contienen varias expresiones cuyo resultado será desplegado po el intérprete de Python

# %%
4 * 6
# Out:
# 24

# %%
15 + 23 # El resultado es 38
# Out:
# 38

# %% [markdown]
# # Docstrings
# Python tambien permite incluir comentarios de varias lineas. Estos deben de estar entre triples comillas `"""` o entre triples apostrofes `'''`
#
# Este tipo de comentarios son conocidos com "docstrings" y son utilizados para generar documentación que se desplegaría mediante la función help()
#
# La siguiente celda define una función con fombre funcion(), la cual incluye un docstring al principio de esta u otro al final

# %%
def funcion():
  """Ejemplo del uso de una docstring"""
  print("hola")
  """Este es otro docstring
  no formara parte de la función"""

# %% [markdown]
# Una vez que fue definida funcion(), el primer docstring será parte de la documentación

# %%
help(funcion)
# Out:
# Help on function funcion in module __main__:
#
# funcion()
#     Ejemplo del uso de una docstring
